# %% [markdown]
# # Stitching Statements
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](http://colab.research.google.com/github/dgunning/edgartools/blob/main/notebooks/XBRL2-StitchingStatements.ipynb)

# %%
# !pip install edgartools
# Out:
# Requirement already satisfied: edgartools in c:\python\docling-sec\.venv\lib\site-packages (4.31.0)
# Requirement already satisfied: beautifulsoup4>=4.10.0 in c:\python\docling-sec\.venv\lib\site-packages (from edgartools) (4.14.2)
# Requirement already satisfied: hishel==0.1.3 in c:\python\docling-sec\.venv\lib\site-packages (from edgartools) (0.1.3)
# Requirement already satisfied: httpx>=0.25.0 in c:\python\docling-sec\.venv\lib\site-packages (from edgartools) (0.28.1)
# Requirement already satisfied: httpxthrottlecache>=0.1.6 in c:\python\docling-sec\.venv\lib\site-packages (from edgartools) (0.2.1)
# Requirement already satisfied: humanize>=4.0.0 in c:\python\docling-sec\.venv\lib\site-packages (from edgartools) (4.14.0)
# Requirement already satisfied: jinja2>=3.1.0 in c:\python\docling-sec\.venv\lib\site-packages (from edgartools) (3.1.6)
# Requirement already satisfied: lxml>=4.4 in c:\python\docling-sec\.venv\lib\site-packages (from edgartools) (6.0.2)
# Requirement already satisfied: nest-asyncio>=1.5.1 in c:\python\docling-sec\.venv\lib\site-packages (from edgartools) (1.6.0)
# Requirement already satisfied: orjson>=3.6.0 in c:\python\docling-sec\.venv\lib\site-packages (from edgartools) (3.11.4)
# Requirement already satisfied: pandas>=2.0.0 in c:\python\docling-sec\.venv\lib\site-packages (from edgartools) (2.3.3)
# Requirement already satisfied: pyarrow>=17.0.0 in c:\python\docling-sec\.venv\lib\site-packages (from edgartools) (21.0.0)
# Requirement already satisfied: pydantic>=2.0.0 in c:\python\docling-sec\.venv\lib\site-packages (from edgartools) (2.12.4)
# Requirement already satisfied: rank-bm25>=0.2.1 in c:\python\docling-sec\.venv\lib\site-packages (from edgartools) (0.2.2)
# Requirement already satisfied: rapidfuzz>=3.5.0 in c:\python\docling-sec\.venv\lib\site-packages (from edgartools) (3.14.3)
# Requirement already satisfied: rich>=13.8.0 in c:\python\docling-sec\.venv\lib\site-packages (from edgartools) (14.2.0)
# Requirement already satisfied: stamina>=24.2.0 in c:\python\docling-sec\.venv\lib\site-packages (from edgartools) (25.1.0)
# Requirement already satisfied: tabulate>=0.9.0 in c:\python\docling-sec\.venv\lib\site-packages (from edgartools) (0.9.0)
# Requirement already satisfied: textdistance>=4.5.0 in c:\python\docling-sec\.venv\lib\site-packages (from edgartools) (4.6.3)
# Requirement already satisfied: tqdm>=4.62.0 in c:\python\docling-sec\.venv\lib\site-packages (from edgartools) (4.67.1)
# Requirement already satisfied: unidecode>=1.2.0 in c:\python\docling-sec\.venv\lib\site-packages (from edgartools) (1.4.0)
# Requirement already satisfied: soupsieve>1.2 in c:\python\docling-sec\.venv\lib\site-packages (from beautifulsoup4>=4.10.0->edgartools) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\python\docling-sec\.venv\lib\site-packages (from beautifulsoup4>=4.10.0->edgartools) (4.15.0)
# Requirement already satisfied: anyio in c:\python\docling-sec\.venv\lib\site-packages (from httpx>=0.25.0->edgartools) (4.11.0)
# Requirement already satisfied: certifi in c:\python\docling-sec\.venv\lib\site-packages (from httpx>=0.25.0->edgartools) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\python\docling-sec\.venv\lib\site-packages (from httpx>=0.25.0->edgartools) (1.0.9)
# Requirement already satisfied: idna in c:\python\docling-sec\.venv\lib\site-packages (from httpx>=0.25.0->edgartools) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\python\docling-sec\.venv\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->edgartools) (0.16.0)
# Requirement already satisfied: aiofiles>=24.1.0 in c:\python\docling-sec\.venv\lib\site-packages (from httpxthrottlecache>=0.1.6->edgartools) (25.1.0)
# Requirement already satisfied: filelock>=3.18.0 in c:\python\docling-sec\.venv\lib\site-packages (from httpxthrottlecache>=0.1.6->edgartools) (3.20.0)
# Requirement already satisfied: pyrate-limiter>=3.9.0 in c:\python\docling-sec\.venv\lib\site-packages (from httpxthrottlecache>=0.1.6->edgartools) (3.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\python\docling-sec\.venv\lib\site-packages (from jinja2>=3.1.0->edgartools) (3.0.3)
# Requirement already satisfied: numpy>=1.23.2 in c:\python\docling-sec\.venv\lib\site-packages (from pandas>=2.0.0->edgartools) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\python\docling-sec\.venv\lib\site-packages (from pandas>=2.0.0->edgartools) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\python\docling-sec\.venv\lib\site-packages (from pandas>=2.0.0->edgartools) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\python\docling-sec\.venv\lib\site-packages (from pandas>=2.0.0->edgartools) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\python\docling-sec\.venv\lib\site-packages (from pydantic>=2.0.0->edgartools) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\python\docling-sec\.venv\lib\site-packages (from pydantic>=2.0.0->edgartools) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\python\docling-sec\.venv\lib\site-packages (from pydantic>=2.0.0->edgartools) (0.4.2)
# Requirement already satisfied: six>=1.5 in c:\python\docling-sec\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->edgartools) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\python\docling-sec\.venv\lib\site-packages (from rich>=13.8.0->edgartools) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\python\docling-sec\.venv\lib\site-packages (from rich>=13.8.0->edgartools) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\python\docling-sec\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->edgartools) (0.1.2)
# Requirement already satisfied: tenacity in c:\python\docling-sec\.venv\lib\site-packages (from stamina>=24.2.0->edgartools) (9.1.2)
# Requirement already satisfied: colorama in c:\python\docling-sec\.venv\lib\site-packages (from tqdm>=4.62.0->edgartools) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\python\docling-sec\.venv\lib\site-packages (from anyio->httpx>=0.25.0->edgartools) (1.3.1)

# %%
from edgar import *
from edgar.xbrl import *
import set_identity


set_identity("philfoden@england.co.uk")

stocks = popular_us_stocks()
tickers = stocks.Ticker.to_list()

ticker = tickers[0]
ticker
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 3
#       1 from edgar import *
#       2 from edgar.xbrl import *
# ----> 3 import set_identity
#       6 set_identity("philfoden@england.co.uk")
#       8 stocks = popular_us_stocks()
#
# ModuleNotFoundError: No module named 'set_identity'

# %%
c = Company(ticker)
filings = c.get_filings(form="10-K").head(5)
xbrls = XBRLS.from_filings(filings)
c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 c = Company(ticker)
#       2 filings = c.get_filings(form="10-K").head(5)
#       3 xbrls = XBRLS.from_filings(filings)
#
# NameError: name 'Company' is not defined

# %%
balance_sheet = xbrls.statements.balance_sheet()
balance_sheet

# %% [markdown]
# ## Stitching older Apple Statements

# %%
c = Company("AAPL")
filings = c.get_filings(form="10-K", filing_date="2019-01-01:2020-11-05").head(2)
xbrls = XBRLS.from_filings(filings)
xbrls.statements.income_statement()

# %% [markdown]
# ## Quarterly Stitching

# %%
filings = company.get_filings(form="10-Q").head(5)
xbrls = XBRLS.from_filings(filings)
xbrls.statements.income_statement()
